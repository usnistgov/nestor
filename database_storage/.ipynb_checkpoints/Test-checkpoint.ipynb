# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import inspect

import pandas as pd
import matplotlib.pyplot as plt



project_path = os.path.abspath( os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))) + "/../" )
sys.path.insert(0, project_path)
print(project_path)

from database_storage.helper import *

from database_storage.database.database import *
from database_storage.main import *

from database_storage.objects.human import *
from database_storage.objects.issue import *
from database_storage.objects.kpi import *
from database_storage.objects.machine import *
from database_storage.objects.tag import *
from database_storage.objects.maintenanceworkorder import *
# Out:
# /Users/sam11/Git/ml-py

# %% [markdown]
# ## Connect to Database

# %%
databaseSchema_file = os.path.join(project_path ,'database_storage','database', 'DatabaseSchema.yaml')
databaseSchema_dict = openYAMLFile(databaseSchema_file)
# Out:
# yaml file open

# %%
PassWord = 'GREYSTONE!!'
database = DatabaseNeo4J("bolt://127.0.0.1:7687", "neo4j", PassWord, databaseSchema_dict)

# %% [markdown]
# ### get CSV information

# %%
csv_file = os.path.join(project_path ,'data', 'gs_data', 'gs_tool_tag_export.csv')
#csv_file = os.path.join(project_path ,'data', 'test.csv')

dataframe = pd.read_csv(csv_file)
dataframe.fillna("", inplace=True)

#csvSchemas_file = os.path.join(project_path , 'data', 'testCSVheader.yaml')
csvSchemas_file = os.path.join(project_path , 'data',  'gs_data', 'gs_CSVheader.yaml')

csvSchemas_dict = openYAMLFile(csvSchemas_file)
# Out:
# yaml file open

# %% [markdown]
# ### Clean the database

# %%
database.deleteData()
database.dropIndexes()
database.createIndexes()
# Out:
# 1

# %% [markdown]
# ## Store the data

# %%
done = graphDatabase_from_TaggedCSV(database, dataframe, csvSchemas_dict)
# Out:
# 100%|██████████| 3438/3438 [07:38<00:00,  7.49it/s]

# %% [markdown]
# # KPI

# %% [markdown]
# ## Create the object for the KPI

# %%
kpiDict = {
    'issue':{
            'description_problem': None,
            'description_solution': None,
            'description_cause': None,
            'description_effect': None,
            'machine_down': None,
            'necessary_part': None,
            'part_in_process': None,

            'date_machine_down': None,
            'date_workorder_start': None,
            'date_maintenance_technician_arrive': None,
            'date_problem_found': None,
            'date_part_ordered': None,
            'date_part_received': None,
            'date_problem_solve': None,
            'date_machine_up': None,
            'date_workorder_completion': None
        },
    'human':{
        'name': None
    },
    'operator': {
        'name': None
    },
    'technician': {
        'name': None,
        'skills': None,
        'crafts': None
    },
    'machine': {
        'name': None,
        'manufacturer': None,
        'location': None
    },
    'machine_type': {
        'type': None
    },
    'tag': {
        'keyword': None,
        'synonyms':  None
    },
    'tag_oneGram': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_nGram': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_item': {
        'keyword':  ["low"],
        'synonyms':  None
    },
    'tag_itemAsProblem': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_itemAsSolution': {
        'keyword':  ["pin", "_"],
        'synonyms':  None
    },
    'tag_problem': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_solution': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_unknown': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_poblemItem': {
        'keyword':  None,
        'synonyms':  None
    },
    'tag_solutionItem': {
        'keyword':  ["_"],
        'synonyms':  None
    }
    }
kpi = Kpi(database, kpiDict)
kpi.createObjects()
print(kpi.tag_item)
# Out:
# OBJECT: <class 'database_storage.objects.tag.TagItem'>
# 	Keyword: ['low']
# 	Synonyms: None
# 	similarTo: None
# 	children: None

# %% [markdown]
# ## get the hierarchy of your item

# %%
g = kpi.tree_itemsHierarchie(child= True, parent=True)

# %%
plt.subplot(121)
nx.draw(g[0][0], with_labels=True, font_weight='bold')
plt.subplot(122)
nx.draw(g[0][1], with_labels=True, font_weight='bold')

# %% [markdown]
# ## Create the query to filter the dataframe

# %%
filterQuery = kpi.cypher_filterDatabase()
done, filterResult = database.runQuery(filterQuery)

dataframe = resultToObservationDataframe(filterResult)
dataframe
# Out:
# 346it [00:00, 160268.27it/s]
# tag_item
# tag_itemAsSolution
# tag_solutionItem
#     tag_itemAsSolution.keyword solutionitem_tag.keyword
# 0                          pin             replaced pin
# 1                          pin             replaced pin
# 2                          pin             replaced pin
# 3                          pin             replaced pin
# 4                          pin             replaced pin
# 5                          pin             replaced pin
# 6                          pin             replaced pin
# 7                          pin             replaced pin
# 8                          pin             replaced pin
# 9                          pin             replaced pin
# 10                         pin             replaced pin
# 11                         pin             replaced pin
# 12                         pin             replaced pin
# 13                         pin             replaced pin
# 14                         pin             replaced pin
# 15                         pin             replaced pin
# 16                         pin             replaced pin
# 17                         pin             replaced pin
# 18                         pin             replaced pin
# 19                         pin             replaced pin
# 20                         pin             replaced pin
# 21                         pin             replaced pin
# 22                         pin             replaced pin
# 23                         pin             replaced pin
# 24                         pin             replaced pin
# 25                         pin             replaced pin
# 26                         pin             replaced pin
# 27                         pin             replaced pin
# 28                         pin             replaced pin
# 29                         pin             replaced pin
# ..                         ...                      ...
# 316                        pin                  pin set
# 317                        pin                  pin set
# 318                        pin                  pin set
# 319                        pin                  pin set
# 320                        pin                  pin set
# 321                        pin                  pin set
# 322                        pin                  pin set
# 323                        pin                  pin set
# 324                       prox             table adjust
# 325                      table             table adjust
# 326                        pin           reset operator
# 327                        pin           reset operator
# 328                        pin           reset operator
# 329                      valve              check valve
# 330                      shaft           shaft replaced
# 331                       unit           shaft replaced
# 332                accumulator           shaft replaced
# 333                accumulator           shaft replaced
# 334                       coil            coil replaced
# 335                     module            coil replaced
# 336                       flow             align turret
# 337                     turret             align turret
# 338                     turret             align turret
# 339                   pressure          pressure report
# 340                        pin               repair pin
# 341                        pin               repair pin
# 342                        pin               repair pin
# 343                        pin               repair pin
# 344                       prox              prox remove
# 345                      table              prox remove
#
# [346 rows x 2 columns]

# %%
import getpass

user = getpass.getuser()
password = getpass.getpass("Password:")

# %%
print(user)
print(password)

# %%
class Pass(str):
    def __init__(self):
