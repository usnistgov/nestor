# %%
import pandas as pd
from pathlib import Path

data_dir = Path('..') / 'data'
df = pd.read_csv(data_dir / 'MWOs_anon.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 mach date_received requested_by  \
# 0           0   A5    2015-01-14        Bruce
# 1           1   QA    2015-02-27           QA
# 2           2  A18    2015-02-27      Steve C
# 3           3  A23    2015-02-27      Steve C
# 4           4  A24    2015-02-27        Clark
#
#                                      issue down_y/n date_completed  \
# 0                                 No power        Y     2016-11-16
# 1                Smartscope harness broken        Y     2016-02-27
# 2              Check / Charge Accumulators        N     2016-02-27
# 3                Hyd leak at saw atachment        N     2016-02-27
# 4  CS1008 setup change over / from ARC1004        Y     2016-03-02
#
#                                 tech  \
# 0  angie_henderson, michele_williams
# 1                   gina_moore, tech
# 2                   nathan_maldonado
# 3                   michele_williams
# 4      ethan_adams, michele_williams
#
# ...
